# %% [markdown]
# # Tutorial 2
#
# Cursus vitae congue mauris rhoncus aenean. Commodo nulla facilisi nullam vehicula ipsum a. Tincidunt dui ut ornare lectus sit amet est placerat. Odio euismod lacinia at quis risus sed vulputate odio ut. Duis ultricies lacus sed turpis. Quam vulputate dignissim suspendisse in est ante. Dui vivamus arcu felis bibendum. Nam libero justo laoreet sit amet cursus sit amet.
#
# ## Imports
#
# Arcu non odio euismod lacinia at quis. Orci sagittis eu volutpat odio.

# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib nbagg

# %% [markdown]
# ## Code
#
# Mus mauris vitae ultricies leo integer malesuada nunc vel. Eget mi proin sed libero enim sed. Adipiscing enim eu turpis egestas. Sit amet nulla facilisi morbi tempus. Enim sit amet venenatis urna cursus. Bibendum enim facilisis gravida neque. Lorem dolor sed viverra ipsum nunc. Sed arcu non odio euismod lacinia at quis risus. Quam nulla porttitor massa id neque aliquam vestibulum.

# %% [markdown]
# ### defining widgets and plotting

# %%
x = np.linspace(0, 2, 1000)

fig, ax = plt.subplots(1, figsize=(6, 3))
plt.suptitle('Sine Wave')

def update_plot(amp, phase, freq):
    
    ax.clear()
    y = amp * np.sin(freq * 2 * np.pi * x + phase * 2 * np.pi)
    units = 'amp = {} $(psi)$ \nphase = {} $(s)$ \nfreq = {} $(Hz)$'
    
    ax.plot(x, y, label=units.format(amp, phase, freq))
    ax.set_xlim(x[0], x[-1])
    ax.legend(loc=1)
    ax.set_xlabel('$(s)$')
    plt.show()

amp = widgets.FloatSlider(min=1, max=10, value=1, description='Amp:')
phase = widgets.FloatSlider(min=0, max=5, value=0, description='Phase:')
freq = widgets.FloatSlider(min=1, max=10, value=1, description='Freq:')

widgets.interactive(update_plot, amp=amp, phase=phase, freq=freq)
# Out:
# <img src="data:image/png;base64,..." width="636.2352941176471">
# interactive(children=(FloatSlider(value=1.0, description='Amp:', max=10.0, min=1.0), FloatSlider(value=0.0, de…

# %% [markdown]
# ## Wrapping up
#
# Cursus vitae congue mauris rhoncus aenean. Commodo nulla facilisi nullam vehicula ipsum a. Tincidunt dui ut ornare lectus sit amet est placerat. Odio euismod lacinia at quis risus sed vulputate odio ut. Duis ultricies lacus sed turpis. Quam vulputate dignissim suspendisse in est ante. Dui vivamus arcu felis bibendum. Nam libero justo laoreet sit amet cursus sit amet. Nulla porttitor massa id neque. Massa massa ultricies mi quis hendrerit dolor magna. Pretium viverra suspendisse potenti nullam ac. Massa massa ultricies mi quis hendrerit dolor magna eget est. Ante in nibh mauris cursus mattis molestie. Arcu non odio euismod lacinia at quis. Orci sagittis eu volutpat odio. Eget sit amet tellus cras adipiscing enim.
